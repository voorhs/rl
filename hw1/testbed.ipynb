# %%
from src.deep import experiment

experiment(
    env_name="CartPole-v1",
    n_iter=20,
    n_sessions=100,
    percentile=70
)
# Out:
# mean reward = 38.930, threshold=45.300

# %%
from src.deep import experiment

experiment(
    env_name="Taxi-v3",
    n_iter=20,
    n_sessions=32,
    percentile=90,
    mean_reward_to_win=100
)
# Out:
# mean reward = -4142.031, threshold=-3532.600

# %%
from src.tabular import experiment

experiment(
    env_name="Taxi-v3",
    n_iter=20,
    n_sessions=250,
    percentile=50,
    mean_reward_to_win=100,
    lr=0.5
)
# Out:
# mean reward = -16.708, threshold=-8.000
