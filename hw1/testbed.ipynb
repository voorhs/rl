# %%
from src.deep import experiment

experiment(
    env_name="CartPole-v1",
    n_iter=20,
    n_sessions=100,
    percentile=70
)
# Out:
# mean reward = 38.930, threshold=45.300

# %%
import gymnasium as gym

# env_name = "CartPole-v1"
env_name = "Taxi-v3"
env = gym.make(env_name, render_mode="rgb_array").env

env.reset()
n_actions = env.action_space.n
state_dim = env.observation_space
print(n_actions, state_dim)
# Out:
# 6 Discrete(500)

# %%
for a in dir(env.observation_space):
    if not a.startswith('_'):
        print(a)
# Out:
# contains
# dtype
# from_jsonable
# is_np_flattenable
# n
# np_random
# sample
# seed
# shape
# start
# to_jsonable

# %%
env.action_space
# Out:
# Discrete(6)
